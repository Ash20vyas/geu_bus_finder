# %%
import pandas as pd
dataset = pd.read_csv("dataset.csv")

# %%
dataset.iloc[0]["Reg num"]
# Out:
# 'UK07PA 2334'

# %%
locations = dataset['stops']

# %%
valid_stops = set()
for row in locations:
    x = row.split('-')
    clean = [s.strip().lower() for s in x]
    for s in clean:
        valid_stops.add(s)

# %%
cleanData = []
for address in list(valid_stops):
    temp = address + ', dehradun, india'
    if len(address) > 3:
        cleanData.append(temp)

# %%
cleanData
# Out:
# ['panditwari, dehradun, india',
#  'vikasnagar yatrik hotel, dehradun, india',
#  'ludwala, dehradun, india',
#  'mathurawala, dehradun, india',
#  'raipur, dehradun, india',
#  'doiwala tachiwala, dehradun, india',
#  'dharampur, dehradun, india',
#  'ladpur, dehradun, india',
#  'shaspur, dehradun, india',
#  'mehuwala, dehradun, india',
#  'tehsil, dehradun, india',
#  'geu/gehu, dehradun, india',
#  'balliwalachowk, dehradun, india',
#  'lachiwala, dehradun, india',
#  'kulhal i, dehradun, india',
#  'dilaram bazar, dehradun, india',
#  'badowala, dehradun, india',
#  'no. pulia, dehradun, india',
#  'dobhal chowk, dehradun, india',
#  'binda pul, dehradun, india',
#  'ranipokhri, dehradun, india',
#  'sudhowala, dehradun, india',
#  'ring road, dehradun, india',
#  'bahuwala raja road, dehradun, india',
#  'harbatpur chowk, dehradun, india',
#  'jogiwa rispana, dehradun, india',
#  'krishna chowk, dehradun, india',
#  'jakhan, dehradun, india',
# ...

# %%
dataset.head()
# Out:
#          Reg num  Num     Time        Driver     Contact  \
# 0    UK07PA 2334    3  7.10 AM       Manjeet  8006136454
# 1   UK 07 PA2623   34  7.35 AM        Baldev  7078198090
# 2    UK07PA 4119   51  7.10 AM     Rai Singh  9456707877
# 3  UK 07 PA 3816   46  8.00 AM   Mohar Singh  9759767817
# 4      UA07Q4731   22  8.00 AM  Pratap Singh  9897158551
#
#                                                stops
# 0  Kulhal I-Harbatpur Chowk-Langa Road- Shaspur- ...
# 1  Selaqui Chowk-Sudhowala-Nanda Ki Chowki- Premn...
# 2  Bahuwala Raja Road-Raja Road-Bansiwala-Manduwa...
# 3  Naya Gaon Palio- - Badowala- Telpur-Mehuwala-I...
# 4              Badowala- - Telpur-Mehuwala- ISBT-Geu

# %%
maplist = []
for i in range(len(dataset)):
    temp = {}
    row = dataset.iloc[i]
    temp["reg_num"] = row["Reg num"]
    temp["bus"] = row["Num"]
    temp["start time"] = row["Time"]
    temp["driver"] = row["Contact"]
    stops_string = row["stops"]
    stops = []
    for stop in stops_string.split("-"):
        x = stop.strip() + ", Dehradun, India"
        if len(x) > 3:
            stops.append(x.lower())
    temp["stops"] = stops
    maplist.append(temp)

# %%
maplist
# Out:
# [{'reg_num': 'UK07PA 2334',
#   'bus': 3,
#   'start time': '7.10 AM',
#   'driver': 8006136454,
#   'stops': ['kulhal i, dehradun, india',
#    'harbatpur chowk, dehradun, india',
#    'langa road, dehradun, india',
#    'shaspur, dehradun, india',
#    'selaqui, dehradun, india',
#    'sudhowala, dehradun, india',
#    'nanda ki chowki, dehradun, india',
#    'premnagar, dehradun, india',
#    'panditwari, dehradun, india',
#    'vasan vihar, dehradun, india',
#    'baliwala chowk, dehradun, india',
#    'gms road, dehradun, india',
#    'geu, dehradun, india']},
#  {'reg_num': 'UK 07 PA2623',
#   'bus': 34,
#   'start time': '7.35 AM',
#   'driver': 7078198090,
#   'stops': ['selaqui chowk, dehradun, india',
#    'sudhowala, dehradun, india',
#    'nanda ki chowki, dehradun, india',
#    'premnagar, dehradun, india',
#    'panditwari, dehradun, india',
#    'vasant vihar, dehradun, india',
#    'baliwala chowk, dehradun, india',
#    'gms road, dehradun, india',
# ...

# %%
stopWiseMap = {}
for stop in cleanData:
    busesList = []
    for buses in maplist:
        if stop in buses['stops']:
            busesList.append(buses['bus'])    
    stopWiseMap[stop] = busesList

# %%
a =[{"stop": "badowala, dehradun, india", "loc": [30.301056199999998, 77.9524488]}, {"stop": "supply, dehradun, india", "loc": [30.3699278, 78.05876]}, {"stop": "sudhowala, dehradun, india", "loc": [30.3450839, 77.9361588]}, {"stop": "fountain chowk rispana, dehradun, india", "loc": [30.3021495, 78.0562906]}, {"stop": "mathurawala, dehradun, india", "loc": [30.2617154, 78.03380779999999]}, {"stop": "no. pulia, dehradun, india", "loc": [30.3161365, 78.0412953]}, {"stop": "gms road, dehradun, india", "loc": [30.310004999999997, 78.0078262]}, {"stop": "bansiwala, dehradun, india", "loc": [30.3448035, 77.9038897]}, {"stop": "geu/gehu, dehradun, india", "loc": [30.268570699999998, 77.994788]}, {"stop": "manduwala, dehradun, india", "loc": [30.3880099, 77.94102509999999]}, {"stop": "survey chowk, dehradun, india", "loc": [30.325606800000003, 78.05271139999999]}, {"stop": "ongc chowk, dehradun, india", "loc": [30.3420268, 78.0163954]}, {"stop": "baliwala chowk, dehradun, india", "loc": [30.323914499999997, 78.0113332]}, {"stop": "nanda ki chowki, dehradun, india", "loc": [30.344562099999997, 77.9545906]}, {"stop": "binda pul, dehradun, india", "loc": [30.3265808, 78.03378909999999]}, {"stop": "doiwala lachiwala, dehradun, india", "loc": [30.175877099999997, 78.1242422]}, {"stop": "jogiwa rispana, dehradun, india", "loc": [30.294481, 78.058002]}, {"stop": "vasant vihar, dehradun, india", "loc": [30.3226277, 78.0036994]}, {"stop": "garhi cant, dehradun, india", "loc": [30.3579473, 78.042782]}, {"stop": "kishan nagar, dehradun, india", "loc": [30.333479800000003, 78.02657239999999]}, {"stop": "rajpur, dehradun, india", "loc": [30.384723899999997, 78.089439]}, {"stop": "lachiwala, dehradun, india", "loc": [30.223021199999998, 78.07660360000001]}, {"stop": "dobhal chowk, dehradun, india", "loc": [30.298339499999997, 78.08052570000
ala telpur, dehradun, india", "loc": [30.301056199999998, 77.9524488]}, {"stop": "naya gaon palio, dehradun, india", "loc": [30.363450999999994, 78.0584851]}, {"stop": "kali mandir, dehradun, india", "loc": [30.321460000000002, 78.07434479999999]}, {"stop": "dwarka store, dehradun, india", "loc": [30.3157339, 78.04982749999999]}, {"stop": "bangali kothi, dehradun, india", "loc": [30.285024200000002, 78.039678]}, {"stop": "selaqui, dehradun, india", "loc": [30.368158500000003, 77.86531260000001]}];
a
# Out:
# [{'stop': 'badowala, dehradun, india',
#   'loc': [30.301056199999998, 77.9524488]},
#  {'stop': 'supply, dehradun, india', 'loc': [30.3699278, 78.05876]},
#  {'stop': 'sudhowala, dehradun, india', 'loc': [30.3450839, 77.9361588]},
#  {'stop': 'fountain chowk rispana, dehradun, india',
#   'loc': [30.3021495, 78.0562906]},
#  {'stop': 'mathurawala, dehradun, india',
#   'loc': [30.2617154, 78.03380779999999]},
#  {'stop': 'no. pulia, dehradun, india', 'loc': [30.3161365, 78.0412953]},
#  {'stop': 'gms road, dehradun, india',
#   'loc': [30.310004999999997, 78.0078262]},
#  {'stop': 'bansiwala, dehradun, india', 'loc': [30.3448035, 77.9038897]},
#  {'stop': 'geu/gehu, dehradun, india', 'loc': [30.268570699999998, 77.994788]},
#  {'stop': 'manduwala, dehradun, india',
#   'loc': [30.3880099, 77.94102509999999]},
#  {'stop': 'survey chowk, dehradun, india',
#   'loc': [30.325606800000003, 78.05271139999999]},
#  {'stop': 'ongc chowk, dehradun, india', 'loc': [30.3420268, 78.0163954]},
# ...

# %%
for m in a:
    stop = m['stop']
    busesList = []
    for buses in maplist:
        if stop in buses['stops']:
            busesList.append(buses['bus'])    
    m['buses'] = busesList

# %%
a
# Out:
# [{'stop': 'badowala, dehradun, india',
#   'loc': [30.301056199999998, 77.9524488],
#   'buses': [46, 22]},
#  {'stop': 'supply, dehradun, india',
#   'loc': [30.3699278, 78.05876],
#   'buses': [20, 21]},
#  {'stop': 'sudhowala, dehradun, india',
#   'loc': [30.3450839, 77.9361588],
#   'buses': [3, 34, 51, 47, 37]},
#  {'stop': 'fountain chowk rispana, dehradun, india',
#   'loc': [30.3021495, 78.0562906],
#   'buses': [23, 50, 54, 19]},
#  {'stop': 'mathurawala, dehradun, india',
#   'loc': [30.2617154, 78.03380779999999],
#   'buses': [13]},
#  {'stop': 'no. pulia, dehradun, india',
#   'loc': [30.3161365, 78.0412953],
#   'buses': [54]},
#  {'stop': 'gms road, dehradun, india',
#   'loc': [30.310004999999997, 78.0078262],
#   'buses': [3, 34, 51, 20, 21, 38, 44, 47, 37, 1, 4]},
#  {'stop': 'bansiwala, dehradun, india',
#   'loc': [30.3448035, 77.9038897],
#   'buses': [51, 1, 4]},
#  {'stop': 'geu/gehu, dehradun, india',
#   'loc': [30.268570699999998, 77.994788],
# ...
